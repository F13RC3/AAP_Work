# %%
from PIL import Image
from pytesseract import image_to_string
import pytesseract
import numpy as np
import pandas as pd
import PIL
# from PIL import Image, ImageFilter, ImageEnhance
import cv2
# import colorsys
import dill
# dill.dump_session('Extraction.db')
dill.load_session('Extraction.db')

# %%
 # pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe"

# %% [markdown]
# # Testing

# %%
image = '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P202/U05A54P203-04.jpg'
details = image_text_2(Image.open(image), image )
# Change pixels in the function given below to get better results

# %%
len(details[0])
# details[0]
# Out:
# 771

# %% [markdown]
# # Main function

# %%
import numpy as np
#initial coordinates of name, guardian's relation and name,house number,age,gender.
#Pls edit and change by hit and try like we did in first page extraction
def image_text(x,crop_rectangle_nm = (64,145, 423, 300),crop_rectangle_eid = (175, 115, 548, 140)):
    
    im = Image.open(x)
    im = cv2.bilateralFilter(np.array(im, dtype= np.uint8),9,75,75)
    im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    im = cv2.adaptiveThreshold(np.array(im,dtype=np.uint8), 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 15)
    im = Image.fromarray(im)
    countt = 1
    jj = []
    cropped_im_n = im.crop(crop_rectangle_nm)
    cropped_im_id = im.crop(crop_rectangle_eid)
    c_n = image_to_string(cropped_im_n,config='-c tessedit_char_whitelist=abcdefghijklmnopqrstuvwxyzQWERTYUIOPASDFGHJKLZXCVBNM:-/0123456789 --psm 6')

    details = c_n.splitlines()

    for i in details:
        if len(i)>0:
            if len(i.split(" "))>1:
                jj.append(i)
    if len(jj)==4:
    
        for i in range(0,10):
            for j in range(0,3):
                kk = []


                cropped_im_nm = im.crop(crop_rectangle_nm)
                cropped_im_eid = im.crop(crop_rectangle_eid)
                c_nm = image_to_string(cropped_im_nm,config='-c tessedit_char_whitelist= qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNM:-/0123456789 --psm 6')
                c_id = image_to_string(cropped_im_eid,config='-c tessedit_char_blacklist=qwertyuiopasdfghjklzxcvbnm:-/. --psm 6')
                details = c_nm.splitlines()
    
                for i in details:
                    if len(i)>0:
                        if len(i.split(" "))>1:
                            kk.append(i)

                if len(kk)==4:
                    countt+=1
                    file_name.append(x+str(countt))
                    n = kk[0].strip().split(" ", 2)[-1]
                    f = kk[1].strip().split(" ", 3)[-1]
                    h = kk[2].strip().split(" ", 3)[-1]
                    mm = kk[3].strip().split(":")
                    a = kk[3].split("S")[0].replace(" ", '')[-2:]
        
                    g = kk[3].split("S")[1].replace(" ", '')[3:]
                    gr = kk[1].strip().split(":")[0]
                    cid = c_id.replace(" ", "")
                    name.append(n)
                    father.append(f)
                    hno.append(h)
                    age.append(a)
                    gen.append(g)
                    grel.append(gr)
                    eid.append(cid)



    # Find distance between same category horizontally.
    # For example find distance between starting coordinate of first box NAME and starting coordinate of secnd box NAME on right
    # Make sure we find distance from starting point. Distance should be same for 2nd and 3rd box horizontally as well as for every 4 other value, such as age, sex etc
                crop_rectangle_nm = tuple(np.add(crop_rectangle_nm, (502, 0,502,0)))
                crop_rectangle_eid = tuple(np.add(crop_rectangle_eid, (502, 0,502,0)))
    # Find ditance between third and first box. Which should be 3 times above found distance

            crop_rectangle_nm = tuple(np.subtract(crop_rectangle_nm, (1506, 0,1506,0)))
            crop_rectangle_eid = tuple(np.subtract(crop_rectangle_eid, (1506, 0,1506,0)))

    # Find distance between same category vertically.
    # For example find distance between starting coordinate of first box NAME and starting coordinate of secnd box NAME down
    # Distance should be same for all 10 boxes vertically as well as for every 4 other value, such as age, sex etc
            crop_rectangle_nm = tuple(np.add(crop_rectangle_nm, (0, 196,0,196)))
            crop_rectangle_eid = tuple(np.add(crop_rectangle_eid, (0, 196,0,196)))
    
    else:
        return image_text_2(im,x)


    return name,father,hno,age,gen,file_name,grel,eid

# %%
def image_text_2(im,x):
    crop_rectangle_nm = (64,160, 423, 320)
    crop_rectangle_eid = (175, 136, 548, 162)
    countt = 1 

    for i in range(0,10):
        for j in range(0,3):
            kk = []
            cropped_im_nm = im.crop(crop_rectangle_nm)
            cropped_im_eid = im.crop(crop_rectangle_eid)
            c_nm = image_to_string(cropped_im_nm,config='-c tessedit_char_whitelist= qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNM:-/0123456789 --psm 6')
            c_id = image_to_string(cropped_im_eid,config='-c tessedit_char_blacklist=qwertyuiopasdfghjklzxcvbnm:-/. --psm 6')
            details = c_nm.splitlines()
            for i in details:
                if len(i)>0:
                    if len(i.split(" "))>1:
                        kk.append(i)

            if len(kk)==4:
                countt+=1
                file_name.append(x+str(countt))
                n = kk[0].strip().split(" ", 2)[-1]
                f = kk[1].strip().split(" ", 3)[-1]
                h = kk[2].strip().split(" ", 3)[-1]
                mm = kk[3].strip().split(":")
                a = kk[3].split("S")[0].replace(" ", '')[-2:]
                g = kk[3].split("S")[1].replace(" ", '')[3:]
                gr = kk[1].strip().split(":")[0]
                cid = c_id.replace(" ", "")
                name.append(n)
                father.append(f)
                hno.append(h)
                age.append(a)
                gen.append(g)
                grel.append(gr)
                eid.append(cid)
                

# Find distance between same category horizontally.
# For example find distance between starting coordinate of first box NAME and starting coordinate of secnd box NAME on right
# Make sure we find distance from starting point. Distance should be same for 2nd and 3rd box horizontally as well as for every 4 other value, such as age, sex etc
            crop_rectangle_nm = tuple(np.add(crop_rectangle_nm, (502, 0,502,0)))
            crop_rectangle_eid = tuple(np.add(crop_rectangle_eid, (502, 0,502,0)))
# Find ditance between third and first box. Which should be 3 times above found distance

        crop_rectangle_nm = tuple(np.subtract(crop_rectangle_nm, (1506, 0,1506,0)))
        crop_rectangle_eid = tuple(np.subtract(crop_rectangle_eid, (1506, 0,1506,0)))
# Find distance between same category vertically.
# For example find distance between starting coordinate of first box NAME and starting coordinate of secnd box NAME down
# Distance should be same for all 10 boxes vertically as well as for every 4 other value, such as age, sex etc
        crop_rectangle_nm = tuple(np.add(crop_rectangle_nm, (0, 192,0,194)))
        crop_rectangle_eid = tuple(np.add(crop_rectangle_eid, (0, 192,0,194)))


    return name,father,hno,age,gen,file_name,grel,eid

# %% [markdown]
# ** Removing page 1 and 2 **

# %%
import glob
#Getting all page 2
page_1 = glob.glob('/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P204/*-01.jpg')
#Getting all page 2
page_2 = glob.glob('/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P204/*-02.jpg')
# page_3 = glob.glob('/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P204/*-03.jpg')
#Getting all pages
page_all = glob.glob('/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P204/*.jpg')

# %%
#Removing page 1 from all
temp = [i for i in page_all if i not in page_1]
#Removing page 2 from all
# temp2 = [i for i in temp if i not in page_2]
page_fin = [i for i in temp if i not in page_3]

# %%
# page_fin = glob.glob('/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P202/U05A54P202-04.jpg')
len(page_fin)
# Out:
# 35

# %% [markdown]
# # Optimized code for extraction

# %%
# k, m =divmod(len(page_fin), 1)
page_fin[0].split('/')[-2]
# (page_fin[i * k + min(i, m):(i + 1) * k + min(i + 1, m)] for i in range(n))
# Out:
# 'U05A54P204'

# %%
def split(a, n):
    k, m = divmod(len(a), n)
    return (a[i * k + min(i, m):(i + 1) * k + min(i + 1, m)] for i in range(n))
#Splitting files into 500 parts to increase frequency of saving. Increase the value to save more frequently
#Do not change value after running code once. If want to change value after running. Delete all saved files or do maths
page_fin_split =  list(split(page_fin, 1))
# page_fin_split

# %%
# Count value is the starting value for code to work. If the last file saved before stopping code was '10', count value for running code again should be '11'
count = 1
count_sem = 1
for i in page_fin_split[count-1:]:
    
    name = []
    father = []
    hno = []
    age = []
    gen = []
    grel = []
    file_name = []
    eid = []
    for j in i:
#         n,f,h,a,g,fn,gr,e = image_text_2(Image.open(j), j)
        n,f,h,a,g,fn,gr,e = image_text(j)

        print("page_"+str(count_sem))
        count_sem+=1

    df = pd.DataFrame(np.column_stack([n, e, gr, f, h, a, g, fn]), 
                       columns=['Name','Epic ID', 'G_Relation', 'Guardian', 'House_No','Age','Gen',"File_Name"])
    df.to_excel(page_fin[0].split('/')[-2]+".xlsx",index = False)
    print(count)
    count+=1
# Out:
# page_1
# page_2
# page_3
# page_4
# page_5
# page_6
# page_7
# page_8
# page_9
# page_10
# page_11
# page_12
# page_13
# page_14
# page_15
# page_16
# page_17
# page_18
# page_19
# page_20
# page_21
# page_22
# page_23
# page_24
# page_25
# page_26
# page_27
# page_28
# page_29
# page_30
# page_31
# page_32
# page_33
# page_34
# page_35
# 1

# %%
# len(fn)
# fn
# Out:
# ['/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P202/U05A54P202-03.jpg2',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P202/U05A54P202-03.jpg3',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P202/U05A54P202-03.jpg4',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P202/U05A54P202-03.jpg5',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P202/U05A54P202-03.jpg6',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P202/U05A54P202-03.jpg7',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P202/U05A54P202-03.jpg8',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P202/U05A54P202-03.jpg9',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P202/U05A54P202-03.jpg10',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P202/U05A54P202-03.jpg11',
#  '/e_drive/MCA/Pyhton(Jupyter)/Data Analysis/PDF to JPG/U05A54P202/U05A54P202-03.jpg12',
# ...
